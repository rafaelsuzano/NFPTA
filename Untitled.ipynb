# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)


#
dataFiles =['dados//2019//ConsultaNFP_33176298862.csv','dados//2020//ConsultaNFP_33176298862.csv','dados//2021//ConsultaNFP_33176298862.csv','dados//2022//ConsultaNFP_33176298862.csv','dados//dados//ConsultaNFP_33176298862 (1).csv']
dataFiles =['dados//dados//ConsultaNFP_33176298862 copy.csv']
df = pd.concat((pd.read_csv(filename, sep='	', encoding='utf-16')for filename in dataFiles ))
#df = pd.read_csv("dados//2020//ConsultaNFP_33176298862.csv", sep='	', encoding='utf-16')
df['CNPJ'] = df['CNPJ emit.'].str.replace('.','').str.replace('/','').str.replace('-','')
df["VALORNF"] = df["Valor NF"].str.replace(',','.').astype(float)
df["ANO"] =  pd.DatetimeIndex(df['Data Emissão']).year
df["MES"] = pd.DatetimeIndex(df['Data Emissão']).month
df["DIA"]  = pd.DatetimeIndex(df['Data Emissão']).day
df["SEMANA"] =  pd.DatetimeIndex(df['Data Emissão']).day_name(locale='pt_BR.utf8')
#print(df)

## Group by Ano Conta
dfAnoConta = df.groupby('ANO')['ANO'].count()
#print(dfAnoConta)


## Group by Ano Soma
dfAnoSoma = df.groupby('ANO')['ANO'].sum()
#print(dfAnoSoma)

## Group by Mes Conta
dfMesConta = df.groupby('MES')['MES'].count()
#print(dfMesConta)


## Group by Mes Soma
dfMesSoma = df.groupby('MES')['VALORNF'].sum()
#print(dfMesSoma)



#Select empresa
dfSelectEmitente= df.loc[df['Emitente'] == "AMAZON SERVICOS DE VAREJO DO BRASIL LTDA"]
#print(dfSelectEmitente)



#Select cnpjsenhase
dfSelectCNPJ= df.loc[df['CNPJ emit.'] == "47.508.411/1665-50"]
#print(dfSelectCNPJ)



dfSelectEmitente= df.loc[df['Emitente'] == "AMAZON SERVICOS DE VAREJO DO BRASIL LTDA"]
#print(dfSelectEmitente)

#Group by 1
df2 = dfSelectEmitente.groupby('Emitente')['VALORNF'].sum()
#print(df2)


df3 = df.groupby('Emitente')['VALORNF'].sum()
#print(df3)

#Total de Compras Ano
#df4 = df.groupby('ANO')['ANO'].count()


df10 = df.groupby(['ANO','MES'])['MES'].apply(lambda x : x.count()).reset_index(name='Total')
print("rafael")
print(df10)


df9 = df.groupby('ANO')['VALORNF'].apply(lambda x : x.sum()).reset_index(name='Total')
#print(df9)

df4 = df.groupby('ANO')['ANO'].apply(lambda x : x.count()).reset_index(name='Total')
#print(df4)

ano = df4["ANO"].astype(int).astype(str)
total = df4["Total"]
vlr =  df9["Total"]

plt.bar(ano, total)
plt.title('Total de Compras Ano')

plt.xlabel('Ano')
plt.ylabel('Total')

#plt.plot(ano, total, color='green')

#plt.show()






'''

#Total de Compras Ano $
df5 = df.groupby('ANO')['VALORNF'].sum()
print(df5)


#Total de Emitente Ano $
df5 = df.groupby(['Emitente', 'ANO'])['VALORNF'].sum()
print(df5)



#Total de Emitente Ano $

df6 = df.groupby('Emitente')['Emitente'].count()

# Same as SQL having

print(df6)



df7 = df.groupby(['Emitente', 'ANO'])['Emitente'].apply(lambda x : x.count()).reset_index(name='Total')

print(df7)
df8= df7.loc[df7['Total'] > 25]

print(df8)


'''
# Out:
#              CNPJ emit.                                  Emitente       No.  \
# 4    15.436.940/0002-86  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  25416242
# 5    15.436.940/0001-03  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  53005574
# 8    15.436.940/0001-03  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  52889408
# 9    15.436.940/0001-03  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  52889492
# 11   15.436.940/0008-71  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA   4203649
# ..                  ...                                       ...       ...
# 477  15.436.940/0008-71  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  24288421
# 502  15.436.940/0001-03  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  97392209
# 503  15.436.940/0001-03  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  97392150
# 90   15.436.940/0001-03  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  12969995
# 103  15.436.940/0002-86  AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  13760089
#
#     Data Emissão Valor NF Data Registro Créditos Situação do Crédito  \
# 4     30/12/2020    69,00    30/12/2020     0,00            Liberado
# 5     30/12/2020    29,44    30/12/2020     0,00            Liberado
# 8     28/12/2020     1,99    28/12/2020     0,00            Liberado
# 9     28/12/2020     7,99    28/12/2020     0,00            Liberado
# 11    26/12/2020    39,00    26/12/2020     0,00            Liberado
# ..           ...      ...           ...      ...                 ...
# 477   03/02/2022    80,07    03/02/2022     0,00            Liberado
# 502   16/01/2022     5,25    16/01/2022     0,00            Liberado
# 503   16/01/2022    13,99    16/01/2022     0,00            Liberado
# 90    20/02/2020     7,39    20/02/2020     0,00            Liberado
# 103   05/02/2020    50,10    05/02/2020     0,00            Liberado
#
#                CNPJ  VALORNF   ANO  MES  DIA         SEMANA
# 4    15436940000286    69.00  2020   12   30   Quarta-feira
# 5    15436940000103    29.44  2020   12   30   Quarta-feira
# 8    15436940000103     1.99  2020   12   28  Segunda-feira
# 9    15436940000103     7.99  2020   12   28  Segunda-feira
# 11   15436940000871    39.00  2020   12   26        Sã¡bado
# ..              ...      ...   ...  ...  ...            ...
# 477  15436940000871    80.07  2022    3    2   Quarta-feira
# 502  15436940000103     5.25  2022    1   16        Domingo
# 503  15436940000103    13.99  2022    1   16        Domingo
# 90   15436940000103     7.39  2020    2   20   Quinta-feira
# 103  15436940000286    50.10  2020    5    2        Sã¡bado
#
# [82 rows x 14 columns]
#              CNPJ emit.                              Emitente     No.  \
# 4    15436940000286    69.00  2020   12   30   Quarta-feira
# 5    15436940000103    29.44  2020   12   30   Quarta-feira
# 8    15436940000103     1.99  2020   12   28  Segunda-feira
# 9    15436940000103     7.99  2020   12   28  Segunda-feira
# 11   15436940000871    39.00  2020   12   26        Sã¡bado
# ..              ...      ...   ...  ...  ...            ...
# 477  15436940000871    80.07  2022    3    2   Quarta-feira
# 502  15436940000103     5.25  2022    1   16        Domingo
# 503  15436940000103    13.99  2022    1   16        Domingo
# 90   15436940000103     7.39  2020    2   20   Quinta-feira
# 103  15436940000286    50.10  2020    5    2        Sã¡bado
#
# [82 rows x 14 columns]
# Emitente
# AMAZON SERVICOS DE VAREJO DO BRASIL LTDA    6015.87
# Name: VALORNF, dtype: float64
# Emitente
# 2 HM RESTAURANTE LTDA                                            50.27
# A.D.J. BRILL LTDA                                                20.79
# A.J.S COM. INTERMEDIACAO E AGENCIAMENTO LTDA                    419.00
# A.R.M DE LIMA COMERCIO DE VESTUARIO E ACESSORIOS                149.90
# ADARIA COMERCIO E DISTRIBUIDORA DE UTILIDADES DOMESTICAS EIR     18.99
#                                                                  ...
# WTENNIS COMERCIO ELETRONICO DE ARTIGOS ESPORTIVOS E ACESSORI    488.89
# YELLOW CELL ACESSORIOS PARA CELULARES E INFORMATICA EIRELI       36.65
# ZAN GALPAO DA CONSTRUCAO LTDA                                   197.80
# ZE SOLUCOES TECNOLOGICAS DE COMERCIO DE BEBIDAS L                42.20
# camila cristina marcal                                           78.90
# Name: VALORNF, Length: 475, dtype: float64

# %%
#Total de Compras Ano $
df5 = df.groupby('ANO')['VALORNF'].sum()
print(df5)


#Total de Emitente Ano $
df5 = df.groupby(['Emitente', 'ANO'])['VALORNF'].sum()
print(df5)



#Total de Emitente Ano $

df6 = df.groupby('Emitente')['Emitente'].count()

# Same as SQL having

print(df6)



df7 = df.groupby(['Emitente', 'ANO'])['Emitente'].apply(lambda x : x.count()).reset_index(name='Total')

print(df7)
df8= df7.loc[df7['Total'] > 25]

print(df8)
# Out:
# ANO
# 2019    27867.28
# 2020    59685.90
# 2021    65163.43
# 2022    92374.07
# Name: VALORNF, dtype: float64
# Emitente                                                      ANO
# 2 HM RESTAURANTE LTDA                                         2019     50.27
# A.D.J. BRILL LTDA                                             2020     20.79
# A.J.S COM. INTERMEDIACAO E AGENCIAMENTO LTDA                  2022    419.00
# A.R.M DE LIMA COMERCIO DE VESTUARIO E ACESSORIOS              2021    149.90
# ADARIA COMERCIO E DISTRIBUIDORA DE UTILIDADES DOMESTICAS EIR  2021     18.99
#                                                                        ...
# WTENNIS COMERCIO ELETRONICO DE ARTIGOS ESPORTIVOS E ACESSORI  2021    132.69
# YELLOW CELL ACESSORIOS PARA CELULARES E INFORMATICA EIRELI    2022     36.65
# ZAN GALPAO DA CONSTRUCAO LTDA                                 2020    197.80
# ZE SOLUCOES TECNOLOGICAS DE COMERCIO DE BEBIDAS L             2022     42.20
# camila cristina marcal                                        2022     78.90
# Name: VALORNF, Length: 612, dtype: float64
# Emitente
# 2 HM RESTAURANTE LTDA                                           1
# A.D.J. BRILL LTDA                                               1
# A.J.S COM. INTERMEDIACAO E AGENCIAMENTO LTDA                    1
# A.R.M DE LIMA COMERCIO DE VESTUARIO E ACESSORIOS                1
# ADARIA COMERCIO E DISTRIBUIDORA DE UTILIDADES DOMESTICAS EIR    1
#                                                                ..
# WTENNIS COMERCIO ELETRONICO DE ARTIGOS ESPORTIVOS E ACESSORI    2
# YELLOW CELL ACESSORIOS PARA CELULARES E INFORMATICA EIRELI      1
# ZAN GALPAO DA CONSTRUCAO LTDA                                   1
# ZE SOLUCOES TECNOLOGICAS DE COMERCIO DE BEBIDAS L               1
# camila cristina marcal                                          1
# Name: Emitente, Length: 475, dtype: int64
#                                               Emitente   ANO  Total
# 0                                2 HM RESTAURANTE LTDA  2019      1
# 1                                    A.D.J. BRILL LTDA  2020      1
# 2         A.J.S COM. INTERMEDIACAO E AGENCIAMENTO LTDA  2022      1
# 3     A.R.M DE LIMA COMERCIO DE VESTUARIO E ACESSORIOS  2021      1
# 4    ADARIA COMERCIO E DISTRIBUIDORA DE UTILIDADES ...  2021      1
# ..                                                 ...   ...    ...
# 607  WTENNIS COMERCIO ELETRONICO DE ARTIGOS ESPORTI...  2021      1
# 608  YELLOW CELL ACESSORIOS PARA CELULARES E INFORM...  2022      1
# 609                      ZAN GALPAO DA CONSTRUCAO LTDA  2020      1
# 610  ZE SOLUCOES TECNOLOGICAS DE COMERCIO DE BEBIDAS L  2022      1
# 611                             camila cristina marcal  2022      1
#
# [612 rows x 3 columns]
#                                      Emitente   ANO  Total
# 18   AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  2020     28
# 20   AMAZON SERVICOS DE VAREJO DO BRASIL LTDA  2022     33
# 112            CIA BRASILEIRA DE DISTRIBUICAO  2022     39
# 133             CONFEITARIA SAINT TROPEZ LTDA  2021     31
# 251            GRUPO FARTURA DE HORTIFRUT S A  2020     50
# 465                         RAIA DROGASIL S A  2021     35
# 466                         RAIA DROGASIL S A  2022     39

# %%
df10 = df.groupby(['ANO','MES'])['MES'].apply(lambda x : x.count()).reset_index(name='Total')
print("rafael")
print(df10)


df9 = df.groupby('ANO')['VALORNF'].apply(lambda x : x.sum()).reset_index(name='Total')
#print(df9)

df4 = df.groupby('ANO')['ANO'].apply(lambda x : x.count()).reset_index(name='Total')
#print(df4)

ano = df4["ANO"].astype(int).astype(str)
total = df4["Total"]
vlr =  df9["Total"]

plt.bar(ano, total)
plt.title('Total de Compras Ano')

plt.xlabel('Ano')
plt.ylabel('Total')

#plt.plot(ano, total, color='green')

#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df10 = df.groupby(['ANO','MES'])['MES'].apply(lambda x : x.count()).reset_index(name='Total')
#       2 print("rafael")
#       3 print(df10)
#
# NameError: name 'df' is not defined
